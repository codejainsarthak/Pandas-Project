# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\PYTHON\pandas final\time.csv")

print(df)
# Out:
#    store_id  order_id     order_date     ship_date delivery_date     category  \
# 0      S201      9001     2023-06-01    2023-06-03    2023-06-06         elec
# 1      S201      9001     01/06/2023    03-06-2023    06-06-2023  Electronics
# 2      S202      9002    June 2 2023    2023-06-05    2023-06-08      fashion
# 3      S203      9003     2023.06.03    2023-06-06           NaN         HOME
# 4      S204      9004       03-06-23    2023-06-07    09-06-2023         home
# 5      S205      9005     2023/06/04  invalid_date    2023-06-09         Elec
# 6      S206      9006            NaN    2023-06-08    2023-06-10      Fashion
# 7      S207      9007    05 Jun 2023    2023-06-09    2023-06-12      FASHION
# 8      S208      9008       20230606    2023-06-10    2023-06-13  electronics
# 9      S209      9009     2023-06-07    2023-06-11    2023-06-14         HOME
# 10     S210      9010       07/06/23    2023-06-12    2023-06-15         Elec
# 11     S211      9011     2023-06-08    2023-06-13    2023-06-16      Fashion
# 12     S212      9012     08-06-2023    2023-06-14    2023-06-17         home
# 13     S213      9013    random_text    2023-06-15    2023-06-18         elec
# 14     S214      9014     2023-06-10    2023-06-16    2023-06-19      Fashion
# 15     S215      9015  10th Jun 2023    2023-06-17    2023-06-20  Electronics
# 16     S216      9016     2023-06-11    2023-06-18    2023-06-21         HOME
# 17     S217      9017     11/06/2023    2023-06-19    2023-06-22         Elec
# 18     S218      9018     2023-06-12    2023-06-20    2023-06-23      FASHION
# 19     S219      9019     2023-06-13    2023-06-21           NaN         Home
# 20     S220      9020     2023-06-14    2023-06-22    2023-06-25  electronics
#
#       city  revenue
# 0    delhi    500.0
# 1    Delhi    500.0
# 2   MUMBAI    700.0
# 3   mumbai    300.0
# 4    Delhi    900.0
# 5    delhi   1000.0
# 6   Mumbai   1200.0
# 7    DELHI   1300.0
# 8   Mumbai   1400.0
# 9    Delhi   -200.0
# 10   delhi      NaN
# 11  MUMBAI   1500.0
# 12   Delhi   1600.0
# 13  Mumbai   1700.0
# 14   delhi   1800.0
# 15  Mumbai   1900.0
# 16   Delhi   2000.0
# 17  MUMBAI   2100.0
# 18   Delhi   2200.0
# 19   delhi   2300.0
# 20  Mumbai   2400.0

# %%
df = df.drop_duplicates(subset=["order_id" , "store_id"])
print(df)
# Out:
#    store_id  order_id     order_date     ship_date delivery_date     category  \
# 0      S201      9001     2023-06-01    2023-06-03    2023-06-06         elec
# 2      S202      9002    June 2 2023    2023-06-05    2023-06-08      fashion
# 3      S203      9003     2023.06.03    2023-06-06           NaN         HOME
# 4      S204      9004       03-06-23    2023-06-07    09-06-2023         home
# 5      S205      9005     2023/06/04  invalid_date    2023-06-09         Elec
# 6      S206      9006            NaN    2023-06-08    2023-06-10      Fashion
# 7      S207      9007    05 Jun 2023    2023-06-09    2023-06-12      FASHION
# 8      S208      9008       20230606    2023-06-10    2023-06-13  electronics
# 9      S209      9009     2023-06-07    2023-06-11    2023-06-14         HOME
# 10     S210      9010       07/06/23    2023-06-12    2023-06-15         Elec
# 11     S211      9011     2023-06-08    2023-06-13    2023-06-16      Fashion
# 12     S212      9012     08-06-2023    2023-06-14    2023-06-17         home
# 13     S213      9013    random_text    2023-06-15    2023-06-18         elec
# 14     S214      9014     2023-06-10    2023-06-16    2023-06-19      Fashion
# 15     S215      9015  10th Jun 2023    2023-06-17    2023-06-20  Electronics
# 16     S216      9016     2023-06-11    2023-06-18    2023-06-21         HOME
# 17     S217      9017     11/06/2023    2023-06-19    2023-06-22         Elec
# 18     S218      9018     2023-06-12    2023-06-20    2023-06-23      FASHION
# 19     S219      9019     2023-06-13    2023-06-21           NaN         Home
# 20     S220      9020     2023-06-14    2023-06-22    2023-06-25  electronics
#
#       city  revenue
# 0    delhi    500.0
# 2   MUMBAI    700.0
# 3   mumbai    300.0
# 4    Delhi    900.0
# 5    delhi   1000.0
# 6   Mumbai   1200.0
# 7    DELHI   1300.0
# 8   Mumbai   1400.0
# 9    Delhi   -200.0
# 10   delhi      NaN
# 11  MUMBAI   1500.0
# 12   Delhi   1600.0
# 13  Mumbai   1700.0
# 14   delhi   1800.0
# 15  Mumbai   1900.0
# 16   Delhi   2000.0
# 17  MUMBAI   2100.0
# 18   Delhi   2200.0
# 19   delhi   2300.0
# 20  Mumbai   2400.0

# %%
df["order_date"] = pd.to_datetime(df["order_date"], errors= "coerce")
df["ship_date"] = pd.to_datetime(df["ship_date"], errors= "coerce")
df["delivery_date"] = pd.to_datetime(df["delivery_date"], errors= "coerce")
print(df[["order_date" , "ship_date", "delivery_date"]])
# Out:
#    order_date  ship_date delivery_date
# 0  2023-06-01 2023-06-03    2023-06-06
# 2         NaT 2023-06-05    2023-06-08
# 3         NaT 2023-06-06           NaT
# 4         NaT 2023-06-07           NaT
# 5         NaT        NaT    2023-06-09
# 6         NaT 2023-06-08    2023-06-10
# 7         NaT 2023-06-09    2023-06-12
# 8         NaT 2023-06-10    2023-06-13
# 9  2023-06-07 2023-06-11    2023-06-14
# 10        NaT 2023-06-12    2023-06-15
# 11 2023-06-08 2023-06-13    2023-06-16
# 12        NaT 2023-06-14    2023-06-17
# 13        NaT 2023-06-15    2023-06-18
# 14 2023-06-10 2023-06-16    2023-06-19
# 15        NaT 2023-06-17    2023-06-20
# 16 2023-06-11 2023-06-18    2023-06-21
# 17        NaT 2023-06-19    2023-06-22
# 18 2023-06-12 2023-06-20    2023-06-23
# 19 2023-06-13 2023-06-21           NaT
# 20 2023-06-14 2023-06-22    2023-06-25

# %%
print(df.isna().sum())

df =df.dropna(subset=["order_date" , "ship_date" , "delivery_date"])
print(df)
# Out:
# store_id          0
# order_id          0
# order_date       12
# ship_date         1
# delivery_date     3
# category          0
# city              0
# revenue           1
# dtype: int64
#    store_id  order_id order_date  ship_date delivery_date     category  \
# 0      S201      9001 2023-06-01 2023-06-03    2023-06-06         elec
# 9      S209      9009 2023-06-07 2023-06-11    2023-06-14         HOME
# 11     S211      9011 2023-06-08 2023-06-13    2023-06-16      Fashion
# 14     S214      9014 2023-06-10 2023-06-16    2023-06-19      Fashion
# 16     S216      9016 2023-06-11 2023-06-18    2023-06-21         HOME
# 18     S218      9018 2023-06-12 2023-06-20    2023-06-23      FASHION
# 20     S220      9020 2023-06-14 2023-06-22    2023-06-25  electronics
#
#       city  revenue
# 0    delhi    500.0
# 9    Delhi   -200.0
# 11  MUMBAI   1500.0
# 14   delhi   1800.0
# 16   Delhi   2000.0
# 18   Delhi   2200.0
# 20  Mumbai   2400.0

# %%
df["category"] = df["category"].str.lower().str.strip()
df["city"] = df["city"].str.lower().str.strip()


print(df[["city" , "category"]])


cate_map = {
    "elec": "Electronics",
    "home": "Home",
    "fashion" : "Fashion",
    "electronics": "Electronics"
}

city_map = {
    "mumbai" : "Mumbai",
    "delhi" : "Delhi"
}

df["category"] = df["category"].replace(cate_map)
df["city"] = df["city"].replace(city_map)

print(df[["city" , "category"]])
# Out:
#       city     category
# 0    delhi         elec
# 9    delhi         home
# 11  mumbai      fashion
# 14   delhi      fashion
# 16   delhi         home
# 18   delhi      fashion
# 20  mumbai  electronics
#       city     category
# 0    Delhi  Electronics
# 9    Delhi         Home
# 11  Mumbai      Fashion
# 14   Delhi      Fashion
# 16   Delhi         Home
# 18   Delhi      Fashion
# 20  Mumbai  Electronics

# %%
# print(df["revenue"].describe)

# df["revenue"] = df["revenue"].where(df["revenue"] >= 0)
# print(df)
# Out:
# <bound method NDFrame.describe of 0    NaN
# 9    NaN
# 11   NaN
# 14   NaN
# 16   NaN
# 18   NaN
# 20   NaN
# Name: revenue, dtype: float64>
#    store_id  order_id order_date  ship_date delivery_date     category  \
# 0      S201      9001 2023-06-01 2023-06-03    2023-06-06  Electronics
# 9      S209      9009 2023-06-07 2023-06-11    2023-06-14         Home
# 11     S211      9011 2023-06-08 2023-06-13    2023-06-16      Fashion
# 14     S214      9014 2023-06-10 2023-06-16    2023-06-19      Fashion
# 16     S216      9016 2023-06-11 2023-06-18    2023-06-21         Home
# 18     S218      9018 2023-06-12 2023-06-20    2023-06-23      Fashion
# 20     S220      9020 2023-06-14 2023-06-22    2023-06-25  Electronics
#
#       city  revenue
# 0    Delhi      NaN
# 9    Delhi      NaN
# 11  Mumbai      NaN
# 14   Delhi      NaN
# 16   Delhi      NaN
# 18   Delhi      NaN
# 20  Mumbai      NaN
